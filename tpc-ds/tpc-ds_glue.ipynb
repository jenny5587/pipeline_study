# %% [markdown]
# # Glue Studio Notebook
# You are now running a **Glue Studio** notebook; before you can start using your notebook you *must* start an interactive session.
#
# ## Available Magics
# |          Magic              |   Type       |                                                                        Description                                                                        |
# |-----------------------------|--------------|-----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | %%configure                 |  Dictionary  |  A json-formatted dictionary consisting of all configuration parameters for a session. Each parameter can be specified here or through individual magics. |
# | %profile                    |  String      |  Specify a profile in your aws configuration to use as the credentials provider.                                                                          |
# | %iam_role                   |  String      |  Specify an IAM role to execute your session with.                                                                                                        |
# | %region                     |  String      |  Specify the AWS region in which to initialize a session.                                                                                                 |
# | %session_id                 |  String      |  Returns the session ID for the running session.                                                                                                          |
# | %connections                |  List        |  Specify a comma separated list of connections to use in the session.                                                                                     |
# | %additional_python_modules  |  List        |  Comma separated list of pip packages, s3 paths or private pip arguments.                                                                                 |
# | %extra_py_files             |  List        |  Comma separated list of additional Python files from S3.                                                                                                 |
# | %extra_jars                 |  List        |  Comma separated list of additional Jars to include in the cluster.                                                                                       |
# | %number_of_workers          |  Integer     |  The number of workers of a defined worker_type that are allocated when a job runs. worker_type must be set too.                                          |
# | %glue_version               |  String      |  The version of Glue to be used by this session. Currently, the only valid options are 2.0 and 3.0 (eg: %glue_version 2.0).                               |
# | %security_config            |  String      |  Define a security configuration to be used with this session.                                                                                            |
# | %sql                        |  String      |  Run SQL code. All lines after the initial %%sql magic will be passed as part of the SQL code.                                                            |
# | %streaming                  |  String      |  Changes the session type to Glue Streaming.                                                                                                              |
# | %etl                        |  String      |  Changes the session type to Glue ETL.                                                                                                                    |
# | %status                     |              |  Returns the status of the current Glue session including its duration, configuration and executing user / role.                                          |
# | %stop_session               |              |  Stops the current session.                                                                                                                               |
# | %list_sessions              |              |  Lists all currently running sessions by name and ID.                                                                                                     |
# | %worker_type                |  String      |  Standard, G.1X, *or* G.2X. number_of_workers must be set too. Default is G.1X.                                                                           |
# | %spark_conf                 |  String      |  Specify custom spark configurations for your session. E.g. %spark_conf spark.serializer=org.apache.spark.serializer.KryoSerializer.                      |

# %%
# %number_of_workers 2
# Out:
# Welcome to the Glue Interactive Sessions Kernel
# For more information on available magic commands, please type %help in any new cell.
#
# Please view our Getting Started page to access the most up-to-date information on the Interactive Sessions kernel: https://docs.aws.amazon.com/glue/latest/dg/interactive-sessions.html
# Installed kernel version: 0.37.0
# Previous number of workers: 5
# Setting new number of workers to: 2

# %%
import sys
from awsglue.transforms import *
from awsglue.utils import getResolvedOptions
from pyspark.context import SparkContext
from awsglue.context import GlueContext
from awsglue.job import Job
from pyspark.sql.types import StructType,StructField,ArrayType,MapType,StringType,TimestampType
import pyspark.sql.functions as F

sc = SparkContext.getOrCreate()
glueContext = GlueContext(sc)
spark = glueContext.spark_session
job = Job(glueContext)
# Out:
# Authenticating with environment variables and user-defined glue_role_arn: arn:aws:iam::425511518222:role/jenny-glue-etl-test
# Trying to create a Glue session for the kernel.
# Worker Type: G.1X
# Number of Workers: 2
# Session ID: 62ded44a-d437-49dd-aea6-cc2288d1d603
# Job Type: glueetl
# Applying the following default arguments:
# --glue_kernel_version 0.37.0
# --enable-glue-datacatalog true
# Waiting for session 62ded44a-d437-49dd-aea6-cc2288d1d603 to get into ready status...
# Session 62ded44a-d437-49dd-aea6-cc2288d1d603 has been created.

# %%
# typelist=['sr_df','ss_df','cr_df','cs_df']
# for i in typelist:
#     print(f'select * from split_etl.{i}')
# Out:
# select * from split_etl.sr_df
# select * from split_etl.ss_df
# select * from split_etl.cr_df
# select * from split_etl.cs_df

# %%
schema = StructType(
    [
        StructField('sequence_number', StringType(), True),
        StructField('table_name', StringType(), True),
        StructField('timestamp', StringType(), True),
        StructField('data', ArrayType(MapType(StringType(),MapType(StringType(),StringType(),True),True),True), True)
    ]
)
#구조 다시 확인해보기

# %%
# print(df2.toPandas())
# Out:
#                                                   data
# 0    [{'A': {'wholesale_cost_a': '72.31', 'ext_disc...
# 1    [{'A': {'wholesale_cost_a': '57.52', 'ext_disc...
# 2    [{'A': {'wholesale_cost_a': '73.36', 'ext_disc...
# 3    [{'A': {'wholesale_cost_a': '60.98', 'ext_disc...
# 4    [{'A': {'wholesale_cost_a': '97.06', 'ext_disc...
# ..                                                 ...
# 98   [{'A': {'wholesale_cost_a': '96.82', 'ext_disc...
# 99   [{'A': {'wholesale_cost_a': '82.2', 'ext_disco...
# 100  [{'A': {'wholesale_cost_a': '18.69', 'ext_disc...
# 101  [{'A': {'wholesale_cost_a': '8.21', 'ext_disco...
# 102  [{'A': {'wholesale_cost_a': '28.33', 'ext_disc...
#
# [103 rows x 1 columns]

# %%
typelist=['sr_df','ss_df','cr_df','cs_df']
for i in typelist:
    df = spark.sql(f'select * from split_etl.{i}').select(F.col('data'))
    df1 = df.rdd.map(lambda x:eval(x.__getitem__('data').replace('nan','"nan"'))).toDF(schema)
    df2 = df1.select(F.col('data'))
    df3 = df2.select(df2.data.getItem(0).alias('part0'), df2.data.getItem(1).alias('part1'), df2.data.getItem(2).alias('part2'))
    df4 = df3.select(df3.part0.getItem('A').alias('part00'), df3.part1.getItem('B').alias('part01'), df3.part2.getItem('C').alias('part02'))
    df5 = df4.withColumn('partA', F.map_concat('part00','part01','part02')).select('partA')
    df6 = df5.rdd.map(lambda x: x.__getitem__('partA')).toDF()
    print(df6.toPandas())
    df6.coalesce(1).write.format('parquet').mode('overwrite').save(f's3://jenny-etl-test/glue_split_etl/one_result/{i}')
#show 하면 하나만 나옴.

# %%
df = spark.sql(f'select * from split_etl.cr_df').select(F.col('data'))
df1 = df.rdd.map(lambda x:eval(x.__getitem__('data').replace('nan','"nan"'))).toDF(schema)
df2 = df1.select(F.col('data'))
df3 = df2.select(df2.data.getItem(0).alias('part0'), df2.data.getItem(1).alias('part1'), df2.data.getItem(2).alias('part2'))
df4 = df3.select(df3.part0.getItem('A').alias('part00'), df3.part1.getItem('B').alias('part01'), df3.part2.getItem('C').alias('part02'))
df5 = df4.withColumn('partA', F.map_concat('part00','part01','part02')).select('partA')
df6 = df5.rdd.map(lambda x: x.__getitem__('partA')).toDF()
df6.coalesce(1).write.option('header','true').csv('s3://jenny-etl-test/glue_split_etl/complete2/')
print(df6.toPandas())
#카탈로그환불기록
# Out:
#              address_id         birth_country  ... warehouse_sk      zip
# 0      AAAAAAAANBFECFAA  NETHERLANDS ANTILLES  ...          9.0  51387.0
# 1      AAAAAAAAEINFEFAA         LIECHTENSTEIN  ...          8.0  38370.0
# 2      AAAAAAAADCMEJBAA             GUATEMALA  ...         18.0  80169.0
# 3      AAAAAAAANKCIOCAA            MOZAMBIQUE  ...         18.0  46971.0
# 4      AAAAAAAAEEDJKDAA              CAMBODIA  ...         16.0  43511.0
# ...                 ...                   ...  ...          ...      ...
# 15466  AAAAAAAAMHAMMDAA               COMOROS  ...         11.0  58048.0
# 15467  AAAAAAAAIKHABCAA                   nan  ...          1.0  45124.0
# 15468  AAAAAAAANHMBHEAA             NICARAGUA  ...          3.0  29431.0
# 15469  AAAAAAAAEDIMMCAA                ZAMBIA  ...         14.0      nan
# 15470  AAAAAAAAJAGIPAAA              MONGOLIA  ...          5.0  68605.0
#
# [15471 rows x 56 columns]

# %%
df = spark.sql(f'select * from split_etl.sr_df').select(F.col('data'))
df1 = df.rdd.map(lambda x:eval(x.__getitem__('data').replace('nan','"nan"'))).toDF(schema)
df2 = df1.select(F.col('data'))
df3 = df2.select(df2.data.getItem(0).alias('part0'), df2.data.getItem(1).alias('part1'), df2.data.getItem(2).alias('part2'))
df4 = df3.select(df3.part0.getItem('A').alias('part00'), df3.part1.getItem('B').alias('part01'), df3.part2.getItem('C').alias('part02'))
df5 = df4.withColumn('partA', F.map_concat('part00','part01','part02')).select('partA')
df6 = df5.rdd.map(lambda x: x.__getitem__('partA')).toDF()
df6.coalesce(1).write.option('header','true').csv('s3://jenny-etl-test/glue_split_etl/complete3/')
print(df6.toPandas())
#매장환불기록
# Out:
#       addr_sk         birth_country  ... ticket_number      zip
# 0   3638139.0              SLOVAKIA  ...       1692817  97057.0
# 1   1219126.0     WALLIS AND FUTUNA  ...     207997757  36871.0
# 2   1827261.0     WALLIS AND FUTUNA  ...      27401269  44536.0
# 3   4570468.0               ROMANIA  ...     103368137  40059.0
# 4    354066.0                 GABON  ...       6051988  73604.0
# 5   2249261.0                 GABON  ...      64218649  27057.0
# 6    506957.0              ETHIOPIA  ...     232237788  33003.0
# 7     55542.0              CAMEROON  ...      73383807  33003.0
# 8   1912041.0              CAMEROON  ...      73383807  99003.0
# 9   4621327.0              CAMEROON  ...      73383807  91904.0
# 10  2602725.0            GUADELOUPE  ...     208550850  66192.0
# 11  2347875.0          BURKINA FASO  ...     155584435  58482.0
# 12  5353296.0               IRELAND  ...      44147312  89454.0
# 13  4298223.0               IRELAND  ...     142247766  46534.0
# 14  4723535.0               FINLAND  ...     153797970  50587.0
# 15  4108551.0                BHUTAN  ...     169203511  79275.0
# 16  3948171.0                BHUTAN  ...     169203511  75281.0
# 17  1611147.0               ERITREA  ...      79498560  39231.0
# 18  5028193.0         FAROE ISLANDS  ...      98790090  40162.0
# 19  3193933.0         FAROE ISLANDS  ...      82960098  25281.0
# 20  1631267.0               FINLAND  ...      27158280  88579.0
# 21  4398853.0                POLAND  ...      56337899  38048.0
# 22  4097595.0     EQUATORIAL GUINEA  ...      33052947  48370.0
# 23  5646171.0     EQUATORIAL GUINEA  ...      33052947  58482.0
# 24  1325059.0              PAKISTAN  ...     238605908  37057.0
# 25  2967070.0                BELIZE  ...     139691790  49584.0
# 26  4081240.0              PARAGUAY  ...      10623287  71904.0
# 27  3962434.0              PARAGUAY  ...     157752330  31952.0
# 28  2180581.0              PARAGUAY  ...     157752330  77752.0
# 29  5098544.0              PARAGUAY  ...      76082667  39431.0
# 30  3737494.0           TIMOR-LESTE  ...     227817147  75709.0
# 31   553046.0                 BENIN  ...     202489603  39532.0
# 32  4364055.0                 BENIN  ...      13429070  51387.0
# 33  3434528.0         FRENCH GUIANA  ...       1493475  59231.0
# 34  2770904.0         FRENCH GUIANA  ...      17328920  51387.0
# 35  1244738.0            MONTSERRAT  ...      14755454  37752.0
# 36  3452551.0               GERMANY  ...     119271810  46787.0
# 37  2265045.0  NETHERLANDS ANTILLES  ...     115499188  75709.0
#
# [38 rows x 65 columns]
# /opt/amazon/spark/python/lib/pyspark.zip/pyspark/sql/session.py:366: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead

# %%
df = spark.sql(f'select * from split_etl.ss_df').select(F.col('data'))
df1 = df.rdd.map(lambda x:eval(x.__getitem__('data').replace('nan','"nan"'))).toDF(schema)
df2 = df1.select(F.col('data'))
df3 = df2.select(df2.data.getItem(0).alias('part0'), df2.data.getItem(1).alias('part1'), df2.data.getItem(2).alias('part2'))
df4 = df3.select(df3.part0.getItem('A').alias('part00'), df3.part1.getItem('B').alias('part01'), df3.part2.getItem('C').alias('part02'))
df5 = df4.withColumn('partA', F.map_concat('part00','part01','part02')).select('partA')
df6 = df5.rdd.map(lambda x: x.__getitem__('partA')).toDF()
df6.coalesce(1).write.option('header','true').csv('s3://jenny-etl-test/glue_split_etl/complete3/ss_df')
print(df6.toPandas())
#매장판매기록
# Out:
#         addr_sk               brand  ... wholesale_cost_b      zip
# 0     1781021.0  edu packexporti #1  ...             0.95  19584.0
# 1     2438687.0  importonameless #5  ...             3.65  37838.0
# 2     1099416.0   exportiimporto #2  ...             2.12  35752.0
# 3     1781021.0      scholarcorp #7  ...             1.39  19584.0
# 4     2438687.0     edu packmaxi #5  ...             2.75  37838.0
# ...         ...                 ...  ...              ...      ...
# 5216  3145688.0       brandbrand #2  ...             1.52  35752.0
# 5217  1781021.0     exportibrand #1  ...             3.87  19584.0
# 5218  1099416.0      scholarmaxi #8  ...            36.45  35752.0
# 5219  2438687.0    univunivamalg #5  ...            51.84  37838.0
# 5220  3145688.0       amalgamalg #1  ...             9.19  35752.0
#
# [5221 rows x 72 columns]
# /opt/amazon/spark/python/lib/pyspark.zip/pyspark/sql/session.py:366: UserWarning: Using RDD of dict to inferSchema is deprecated. Use pyspark.sql.Row instead

# %%
## 아래의 코드는 spread Ver.

# %%
import pandas as pd

# df6.coalesce(1).write.option('header','true').csv('s3://jenny-etl-test/glue_split_etl/complete/test')
#카탈로그판매기록

# %%
schema = StructType(
    [
        StructField('sequence_number', StringType(), True),
        StructField('table_name', StringType(), True),
        StructField('timestamp', StringType(), True),
        StructField('data', ArrayType(MapType(StringType(),MapType(StringType(),StringType(),True),True),True), True)
    ]
)
#구조 다시 확인해보기

# %%
df = spark.sql(f'select * from split_etl.ss_df').select(F.col('data'))
df.limit(1).show(truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |{'sequence_number': '31566', 'table_name': '매장판매기록', 'timestamp': '2023-01-17 03:42:00.931062', 'data': [{'A': {'sold_date_sk': 2450816, 'sold_time_sk': 51106, 'item_sk': 41408, 'customer_sk': 1020172.0, 'cdemo_sk': 49553.0, 'hdemo_sk': 4087.0, 'addr_sk': 1781021.0, 'store_sk': 352.0, 'promo_sk': 852.0, 'ticket_number': 220188931, 'quantity': 22.0, 'wholesale_cost_a': 36.67, 'list_price': 70.77, 'sales_price': 32.55, 'ext_discount_amt': 0.0, 'ext_sales_price': 716.1, 'ext_wholesale_cost': 806.74, 'ext_list_price': 1556.94, 'ext_tax': 21.48, 'coupon_amt': 0.0, 'net_paid': 716.1, 'net_paid_inc_tax': 737.58, 'net_profit': -90.64, 'store_id': 'AAAAAAAAAGBAAAAA'}}, {'B': {'rec_start_date_a': '1997-03-13', 'rec_end_date_a': '1999-03-13', 'closed_date_sk': nan, 'store_name': 'able', 'number_employees': 257.0, 'floor_space': 6383749.0, 'hours': '8AM-4PM', 'manager': 'Marcus Watkins', 'market_id': 7.0, 'geography_class': 'Unknown', 'market_desc': 'Indeed secret factors might not keep else computers. Deep, physical speakers shou', 'market_manager': 'James Kilgore', 'division_id': 1.0, 'division_name': 'Unknown', 'company_id': 1.0, 'company_name': 'Unknown', 'street_number': 749.0, 'street_name': 'Railroad Maple', 'street_type': 'Drive', 'suite_number': 'Suite 10', 'city': 'Oakdale', 'county': 'Dauphin County', 'state': 'PA', 'zip': 19584.0}}, {'C': {'country': 'United States', 'gmt_offset': -5.0, 'tax_precentage': 0.09, 'item_id': 'AAAAAAAAAMBKAAAA', 'rec_start_date_b': '1997-10-27', 'rec_end_date_b': '2000-10-26', 'item_desc': 'Members shall withstand short, mad procedures. Good, regional films used to contend too.', 'current_price': 1.29, 'wholesale_cost_b': 0.95, 'brand_id': 3004001.0, 'brand': 'edu packexporti #1', 'class_id': 4.0, 'class': 'school-uniforms', 'category_id': 3.0, 'category': 'Children', 'manufact_id': 489.0, 'manufact': 'n steingese', 'size': 'extra large', 'formulation': '71metallic0275295382', 'color': 'smoke', 'units': 'Ounce', 'container': 'Unknown', 'manager_id': 12.0, 'product_name': 'eingbareseoughtese'}}]}|
# +-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
df1 = df.rdd.map(lambda x:eval(x.__getitem__('data').replace('nan','"nan"'))).toDF(schema)
# -> 이런 표현을 한 화살표가 map으로 인식이 잘 되어있는 것을 뜻함.
# getitem -> python def (개체 가져오는 함수) | 함수 공부 다시 알아보기

# %%
df2 = df1.select(F.col('data'))
df2.show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |data                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[[A -> [ext_list_price -> 1556.94, net_paid_inc_tax -> 737.58, net_paid -> 716.1, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.67, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 22.0, item_sk -> 41408, ext_tax -> 21.48, list_price -> 70.77, ticket_number -> 220188931, promo_sk -> 852.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 32.55, net_profit -> -90.64, ext_sales_price -> 716.1, customer_sk -> 1020172.0, ext_wholesale_cost -> 806.74, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> smoke, class_id -> 4.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 12.0, formulation -> 71metallic0275295382, class -> school-uniforms, brand -> edu packexporti #1, wholesale_cost_b -> 0.95, manufact_id -> 489.0, item_desc -> Members shall withstand short, mad procedures. Good, regional films used to contend too., item_id -> AAAAAAAAAMBKAAAA, product_name -> eingbareseoughtese, brand_id -> 3004001.0, size -> extra large, manufact -> n steingese, current_price -> 1.29, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]]]                                                                                                               |
# |[[A -> [ext_list_price -> 1296.0, net_paid_inc_tax -> 864.96, net_paid -> 816.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 10.87, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 75.0, item_sk -> 12724, ext_tax -> 48.96, list_price -> 17.28, ticket_number -> 28702045, promo_sk -> 145.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 10.88, net_profit -> 0.75, ext_sales_price -> 816.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 815.25, hdemo_sk -> 2519.0]], [B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> steel, class_id -> 12.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 7.0, manager_id -> 64.0, formulation -> 91452chartreuse69324, class -> paint, brand -> importonameless #5, wholesale_cost_b -> 3.65, manufact_id -> 488.0, item_desc -> Together young farmers need of course following officers. Early beans gain there continental animals. Local, his, item_id -> AAAAAAAAELBDAAAA, product_name -> eseableationableought, brand_id -> 7012005.0, size -> nan, manufact -> eingeingese, current_price -> 4.94, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Home]]]                                                                                                      |
# |[[A -> [ext_list_price -> 7357.88, net_paid_inc_tax -> 4698.55, net_paid -> 4561.7, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 91.93, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 58.0, item_sk -> 62191, ext_tax -> 136.85, list_price -> 126.86, ticket_number -> 173554050, promo_sk -> 345.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.65, net_profit -> -770.24, ext_sales_price -> 4561.7, customer_sk -> 1673235.0, ext_wholesale_cost -> 5331.94, hdemo_sk -> 5889.0]], [B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]], [C -> [container -> Unknown, country -> United States, color -> sandy, class_id -> 3.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 1.0, formulation -> 9613lemon44338051332, class -> pants, brand -> exportiimporto #2, wholesale_cost_b -> 2.12, manufact_id -> 370.0, item_desc -> Public provisions would not bring thus well unable women. Gay, opening records increase almost local, capital organisers. White, concerned , item_id -> AAAAAAAAPOCPAAAA, product_name -> oughtn stoughtablecally, brand_id -> 2003002.0, size -> extra large, manufact -> barationpri, current_price -> 6.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]]                                                                                                                     |
# |[[A -> [ext_list_price -> 1463.52, net_paid_inc_tax -> 270.93, net_paid -> 263.04, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 16.94, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 48.0, item_sk -> 52790, ext_tax -> 7.89, list_price -> 30.49, ticket_number -> 220188931, promo_sk -> 44.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 5.48, net_profit -> -550.08, ext_sales_price -> 263.04, customer_sk -> 1020172.0, ext_wholesale_cost -> 813.12, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> floral, class_id -> 5.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 6.0, manager_id -> 2.0, formulation -> seashell957944023811, class -> earings, brand -> scholarcorp #7, wholesale_cost_b -> 1.39, manufact_id -> 355.0, item_desc -> Waste purpose, item_id -> AAAAAAAAGDOMAAAA, product_name -> barn stationableanti, brand_id -> 6005007.0, size -> nan, manufact -> antiantipri, current_price -> 3.77, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Jewelry]]]                                                                                                                                                                                                             |
# |[[A -> [ext_list_price -> 1659.0, net_paid_inc_tax -> 34.32, net_paid -> 33.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 18.94, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 60.0, item_sk -> 102334, ext_tax -> 1.32, list_price -> 27.65, ticket_number -> 28702045, promo_sk -> 888.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 0.55, net_profit -> -1103.4, ext_sales_price -> 33.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 1136.4, hdemo_sk -> 2519.0]], [B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> chocolate, class_id -> 14.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 498138510204rosy8801, class -> tennis, brand -> edu packmaxi #5, wholesale_cost_b -> 2.75, manufact_id -> 218.0, item_desc -> Hands , item_id -> AAAAAAAAOLPIBAAA, product_name -> esepripriablebarought, brand_id -> 8014005.0, size -> nan, manufact -> eingoughtable, current_price -> 4.17, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Sports]]]                                                                                                                                                                                                           |
# |[[A -> [ext_list_price -> 3738.0, net_paid_inc_tax -> 1453.24, net_paid -> 1345.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 79.88, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 40.0, item_sk -> 28729, ext_tax -> 107.64, list_price -> 93.45, ticket_number -> 173554050, promo_sk -> 1129.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 33.64, net_profit -> -1849.6, ext_sales_price -> 1345.6, customer_sk -> 1673235.0, ext_wholesale_cost -> 3195.2, hdemo_sk -> 5889.0]], [B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]], [C -> [container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 8.0, formulation -> 7653metallic23918651, class -> school-uniforms, brand -> edu packexporti #2, wholesale_cost_b -> 1.93, manufact_id -> 627.0, item_desc -> Days can include then political periods. Now great players will not know. Cheap, domestic tiles say finally eastern tests. Environmental, good communities can claim in a ministers. Extr, item_id -> AAAAAAAAJDAHAAAA, product_name -> n stableationeingable, brand_id -> 3004002.0, size -> medium, manufact -> ationablecally, current_price -> 3.07, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Children]]]                                                              |
# |[[A -> [ext_list_price -> 190.05, net_paid_inc_tax -> 50.29, net_paid -> 48.36, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 23.82, cdemo_sk -> 705962.0, ext_discount_amt -> 23.81, quantity -> 7.0, item_sk -> 84853, ext_tax -> 1.93, list_price -> 27.15, ticket_number -> 173554050, promo_sk -> 110.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 23.81, sales_price -> 10.31, net_profit -> -118.38, ext_sales_price -> 72.17, customer_sk -> 1673235.0, ext_wholesale_cost -> 166.74, hdemo_sk -> 5889.0]], [B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]], [C -> [container -> Unknown, country -> United States, color -> cyan, class_id -> 1.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 4.0, manager_id -> 7.0, formulation -> 449maroon14401579075, class -> womens, brand -> amalgedu pack #2, wholesale_cost_b -> 0.05, manufact_id -> 137.0, item_desc -> International, stro, item_id -> AAAAAAAAFHLEBAAA, product_name -> priantieingeseeing, brand_id -> 4001002.0, size -> medium, manufact -> ationpriought, current_price -> 0.18, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Shoes]]]                                                                                                                                                                                                                                                          |
# |[[A -> [ext_list_price -> 15011.64, net_paid_inc_tax -> 4170.12, net_paid -> 3971.55, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 83.68, cdemo_sk -> 49553.0, ext_discount_amt -> 81.05, quantity -> 92.0, item_sk -> 53440, ext_tax -> 198.57, list_price -> 163.17, ticket_number -> 220188931, promo_sk -> 485.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 81.05, sales_price -> 44.05, net_profit -> -3727.01, ext_sales_price -> 4052.6, customer_sk -> 1020172.0, ext_wholesale_cost -> 7698.56, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> dodger, class_id -> 12.0, tax_precentage -> 0.09, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 10.0, manager_id -> 53.0, formulation -> purple93389253847893, class -> monitors, brand -> importoamalgamalg #10, wholesale_cost_b -> 6.65, manufact_id -> 309.0, item_desc -> Always free loans stay officially at the things. Simple agents develop states. Sudden, royal feet miss results. Spirits may not get thus; public, labour men lay therefore. Popular opponents should, item_id -> AAAAAAAAAMANAAAA, product_name -> bareseeseprianti, brand_id -> 1.001201E7, size -> nan, manufact -> n stbarpri, current_price -> 9.51, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Electronics]]]|
# |[[A -> [ext_list_price -> 274.0, net_paid_inc_tax -> 274.0, net_paid -> 274.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 2.59, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 100.0, item_sk -> 139063, ext_tax -> 0.0, list_price -> 2.74, ticket_number -> 183648904, promo_sk -> 769.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 2.74, net_profit -> 15.0, ext_sales_price -> 274.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 259.0, hdemo_sk -> 5819.0]], [B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.06, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 6.0, formulation -> 07468221505white7068, class -> sports-apparel, brand -> edu packimporto #2, wholesale_cost_b -> 1.0, manufact_id -> 98.0, item_desc -> Late, private hands like never; underlying, ordinary remains could try less, item_id -> AAAAAAAAHDPBCAAA, product_name -> pricallybarn stpriought, brand_id -> 2004002.0, size -> large, manufact -> eingn st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]]                                                                                                                                                                                               |
# |[[A -> [ext_list_price -> 2891.61, net_paid_inc_tax -> 661.56, net_paid -> 636.12, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 32.11, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 57.0, item_sk -> 19075, ext_tax -> 25.44, list_price -> 50.73, ticket_number -> 173554050, promo_sk -> 830.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 11.16, net_profit -> -1194.15, ext_sales_price -> 636.12, customer_sk -> 1673235.0, ext_wholesale_cost -> 1830.27, hdemo_sk -> 5889.0]], [B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]], [C -> [container -> Unknown, country -> United States, color -> sandy, class_id -> 2.0, tax_precentage -> 0.09, units -> nan, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 16.0, formulation -> 9149881metallic66497, class -> fragrances, brand -> importoamalg #2, wholesale_cost_b -> 0.58, manufact_id -> 936.0, item_desc -> Big, different principles test in particular. Qualifications could not turn above high types. Errors help here red enquiries; particl, item_id -> AAAAAAAADIKEAAAA, product_name -> antiationbarn stought, brand_id -> 1002002.0, size -> large, manufact -> callyprin st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]]]                                                                                                                                 |
# |[[A -> [ext_list_price -> 5449.6, net_paid_inc_tax -> 2397.6, net_paid -> 2397.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 37.64, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 80.0, item_sk -> 67807, ext_tax -> 0.0, list_price -> 68.12, ticket_number -> 183648904, promo_sk -> 1014.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 29.97, net_profit -> -613.6, ext_sales_price -> 2397.6, customer_sk -> 3422434.0, ext_wholesale_cost -> 3011.2, hdemo_sk -> 5819.0]], [B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> puff, class_id -> 1.0, tax_precentage -> 0.06, units -> Pallet, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 63.0, formulation -> 061995154308tomato83, class -> accessories, brand -> amalgimporto #2, wholesale_cost_b -> 0.52, manufact_id -> 295.0, item_desc -> Prior official years must not waive frequent, silly differences. Specific, colourful interests may not find. Years increase golden disciplines. Still current failures take now th, item_id -> AAAAAAAAPNIABAAA, product_name -> ationbareingationcally, brand_id -> 2001002.0, size -> small, manufact -> antin stable, current_price -> 0.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]]                                                                                 |
# |[[A -> [ext_list_price -> 533.8, net_paid_inc_tax -> 48.96, net_paid -> 48.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 45.24, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 10.0, item_sk -> 187726, ext_tax -> 0.96, list_price -> 53.38, ticket_number -> 220188931, promo_sk -> 790.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 4.8, net_profit -> -404.4, ext_sales_price -> 48.0, customer_sk -> 1020172.0, ext_wholesale_cost -> 452.4, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> tan, class_id -> 2.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 61.0, formulation -> 9176519302red4209322, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 0.45, manufact_id -> 316.0, item_desc -> Metres could not create more important, recent eyebrows. Individual elements must like. Working, nuclear reactions get better perhaps other fruits. Options used to want dark, educatio, item_id -> AAAAAAAAOENNCAAA, product_name -> callyableationationeingought, brand_id -> 2002001.0, size -> medium, manufact -> callyoughtpri, current_price -> 1.41, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]]]                                  |
# |[[A -> [ext_list_price -> 1049.28, net_paid_inc_tax -> 320.19, net_paid -> 293.76, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 69.4, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 12.0, item_sk -> 200822, ext_tax -> 26.43, list_price -> 87.44, ticket_number -> 220188931, promo_sk -> 288.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 24.48, net_profit -> -539.04, ext_sales_price -> 293.76, customer_sk -> 1020172.0, ext_wholesale_cost -> 832.8, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> peach, class_id -> 2.0, tax_precentage -> 0.09, units -> Ton, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 2.0, formulation -> 425433slate288781353, class -> infants, brand -> importoexporti #1, wholesale_cost_b -> 1.07, manufact_id -> 388.0, item_desc -> Usually english services cannot say more little states. Domi"nan"t, free managers will see home long-term, middle applications; dreadful, general branch, item_id -> AAAAAAAAGHABDAAA, product_name -> ableableeingbarbarable, brand_id -> 3002001.0, size -> economy, manufact -> eingeingpri, current_price -> 3.26, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]]]                                                         |
# |[[A -> [ext_list_price -> 3186.4, net_paid_inc_tax -> 1451.47, net_paid -> 1395.65, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 47.82, cdemo_sk -> 49553.0, ext_discount_amt -> 516.19, quantity -> 56.0, item_sk -> 278278, ext_tax -> 55.82, list_price -> 56.9, ticket_number -> 220188931, promo_sk -> 138.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 516.19, sales_price -> 34.14, net_profit -> -1282.27, ext_sales_price -> 1911.84, customer_sk -> 1020172.0, ext_wholesale_cost -> 2677.92, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> white, class_id -> 2.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 15.0, formulation -> magenta5144903790234, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 2.46, manufact_id -> 653.0, item_desc -> Previous, public patterns could not ove, item_id -> AAAAAAAAGAPDEAAA, product_name -> eingationableeingationable, brand_id -> 2002001.0, size -> medium, manufact -> priantically, current_price -> 4.48, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]]]                                                                                                                                                             |
# |[[A -> [ext_list_price -> 4620.33, net_paid_inc_tax -> 699.93, net_paid -> 693.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 81.88, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 33.0, item_sk -> 164011, ext_tax -> 6.93, list_price -> 140.01, ticket_number -> 183648904, promo_sk -> 730.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 21.0, net_profit -> -2009.04, ext_sales_price -> 693.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 2702.04, hdemo_sk -> 5819.0]], [B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> peru, class_id -> 3.0, tax_precentage -> 0.06, units -> Each, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 98.0, formulation -> 73645025cyan74975996, class -> maternity, brand -> exportiamalg #2, wholesale_cost_b -> 6.73, manufact_id -> 339.0, item_desc -> Appropriate, central plans can obtain soon as dramatic par, item_id -> AAAAAAAALKAICAAA, product_name -> oughtoughtbaresecallyought, brand_id -> 1003002.0, size -> extra large, manufact -> n stpripri, current_price -> 8.31, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]]]                                                                                                                                                                                                |
# |[[A -> [ext_list_price -> 9495.9, net_paid_inc_tax -> 7658.66, net_paid -> 7026.3, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 78.74, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 90.0, item_sk -> 297448, ext_tax -> 632.36, list_price -> 105.51, ticket_number -> 28702045, promo_sk -> 1236.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.07, net_profit -> -60.3, ext_sales_price -> 7026.3, customer_sk -> 8820136.0, ext_wholesale_cost -> 7086.6, hdemo_sk -> 2519.0]], [B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> steel, class_id -> 3.0, tax_precentage -> 0.11, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 49.0, formulation -> 81398slate0530344627, class -> maternity, brand -> exportiamalg #1, wholesale_cost_b -> 3.15, manufact_id -> 505.0, item_desc -> Reasonable police go often important, popular parents. Years live perhaps internal children. Ye, item_id -> AAAAAAAAIOJIEAAA, product_name -> eingeseeseationn stable, brand_id -> 1003001.0, size -> extra large, manufact -> antibaranti, current_price -> 3.75, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Women]]]                                                                                                |
# |[[A -> [ext_list_price -> 1882.44, net_paid_inc_tax -> 1097.58, net_paid -> 1016.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.89, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 27.0, item_sk -> 208819, ext_tax -> 81.3, list_price -> 69.72, ticket_number -> 220188931, promo_sk -> 315.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 37.64, net_profit -> 20.25, ext_sales_price -> 1016.28, customer_sk -> 1020172.0, ext_wholesale_cost -> 996.03, hdemo_sk -> 4087.0]], [B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> rosy, class_id -> 2.0, tax_precentage -> 0.09, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 5.0, manager_id -> 39.0, formulation -> 8321770medium0611592, class -> country, brand -> importoscholar #2, wholesale_cost_b -> 0.6, manufact_id -> 238.0, item_desc -> Both national visitors could develop please in a drawings. Free recommendations, item_id -> AAAAAAAADLPCDAAA, product_name -> n stoughteingeingbarable, brand_id -> 5002002.0, size -> nan, manufact -> eingpriable, current_price -> 1.32, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Music]]]                                                                                                                                         |
# |[[A -> [ext_list_price -> 7129.56, net_paid_inc_tax -> 7160.65, net_paid -> 6630.24, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 48.11, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 76.0, item_sk -> 169159, ext_tax -> 530.41, list_price -> 93.81, ticket_number -> 183648904, promo_sk -> 1128.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 87.24, net_profit -> 2973.88, ext_sales_price -> 6630.24, customer_sk -> 3422434.0, ext_wholesale_cost -> 3656.36, hdemo_sk -> 5819.0]], [B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> sienna, class_id -> 11.0, tax_precentage -> 0.06, units -> Box, rec_start_date_b -> 1997-10-27, category_id -> 9.0, manager_id -> 33.0, formulation -> 421salmon06995416651, class -> cooking, brand -> amalgunivamalg #8, wholesale_cost_b -> 1.49, manufact_id -> 541.0, item_desc -> Hands cannot turn annual, economic topics. Enormous, local women praise to a fears. British problems must not increase suddenly complicated years. Her, item_id -> AAAAAAAAHMEJCAAA, product_name -> n stantioughtn stcallyought, brand_id -> 9011008.0, size -> nan, manufact -> oughteseanti, current_price -> 4.28, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Books]]]                                                                                                |
# |[[A -> [ext_list_price -> 10972.5, net_paid_inc_tax -> 5517.88, net_paid -> 5156.9, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 99.21, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 70.0, item_sk -> 195668, ext_tax -> 360.98, list_price -> 156.75, ticket_number -> 183648904, promo_sk -> 1344.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 73.67, net_profit -> -1787.8, ext_sales_price -> 5156.9, customer_sk -> 3422434.0, ext_wholesale_cost -> 6944.7, hdemo_sk -> 5819.0]], [B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> rosy, class_id -> 8.0, tax_precentage -> 0.06, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 9391plum055252741816, class -> outdoor, brand -> namelessnameless #9, wholesale_cost_b -> 3.53, manufact_id -> 531.0, item_desc -> Black, steep figures should show., item_id -> AAAAAAAAEFMPCAAA, product_name -> eingcallycallyantin stought, brand_id -> 8008009.0, size -> nan, manufact -> oughtprianti, current_price -> 4.98, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Sports]]]                                                                                                                                                                                                                 |
# |[[A -> [ext_list_price -> 6557.58, net_paid_inc_tax -> 68.54, net_paid -> 65.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 69.13, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 51.0, item_sk -> 237896, ext_tax -> 3.26, list_price -> 128.58, ticket_number -> 28702045, promo_sk -> 37.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 1.28, net_profit -> -3460.35, ext_sales_price -> 65.28, customer_sk -> 8820136.0, ext_wholesale_cost -> 3525.63, hdemo_sk -> 2519.0]], [B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]], [C -> [container -> Unknown, country -> United States, color -> smoke, class_id -> 3.0, tax_precentage -> 0.11, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 69.0, formulation -> 3168761438497slate28, class -> pants, brand -> exportiimporto #1, wholesale_cost_b -> 2.24, manufact_id -> 131.0, item_desc -> Flowers should try from a rooms. Primari, item_id -> AAAAAAAAIEBKDAAA, product_name -> callyn steingationpriable, brand_id -> 2003001.0, size -> extra large, manufact -> oughtpriought, current_price -> 4.08, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Men]]]                                                                                                                                                            |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
df2.select(df2.data.getItem(0).alias('part0')).show(truncate=False)
#part0에 A만 가져오기
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |part0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[A -> [ext_list_price -> 1556.94, net_paid_inc_tax -> 737.58, net_paid -> 716.1, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.67, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 22.0, item_sk -> 41408, ext_tax -> 21.48, list_price -> 70.77, ticket_number -> 220188931, promo_sk -> 852.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 32.55, net_profit -> -90.64, ext_sales_price -> 716.1, customer_sk -> 1020172.0, ext_wholesale_cost -> 806.74, hdemo_sk -> 4087.0]]              |
# |[A -> [ext_list_price -> 1296.0, net_paid_inc_tax -> 864.96, net_paid -> 816.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 10.87, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 75.0, item_sk -> 12724, ext_tax -> 48.96, list_price -> 17.28, ticket_number -> 28702045, promo_sk -> 145.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 10.88, net_profit -> 0.75, ext_sales_price -> 816.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 815.25, hdemo_sk -> 2519.0]]                |
# |[A -> [ext_list_price -> 7357.88, net_paid_inc_tax -> 4698.55, net_paid -> 4561.7, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 91.93, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 58.0, item_sk -> 62191, ext_tax -> 136.85, list_price -> 126.86, ticket_number -> 173554050, promo_sk -> 345.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.65, net_profit -> -770.24, ext_sales_price -> 4561.7, customer_sk -> 1673235.0, ext_wholesale_cost -> 5331.94, hdemo_sk -> 5889.0]]      |
# |[A -> [ext_list_price -> 1463.52, net_paid_inc_tax -> 270.93, net_paid -> 263.04, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 16.94, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 48.0, item_sk -> 52790, ext_tax -> 7.89, list_price -> 30.49, ticket_number -> 220188931, promo_sk -> 44.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 5.48, net_profit -> -550.08, ext_sales_price -> 263.04, customer_sk -> 1020172.0, ext_wholesale_cost -> 813.12, hdemo_sk -> 4087.0]]              |
# |[A -> [ext_list_price -> 1659.0, net_paid_inc_tax -> 34.32, net_paid -> 33.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 18.94, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 60.0, item_sk -> 102334, ext_tax -> 1.32, list_price -> 27.65, ticket_number -> 28702045, promo_sk -> 888.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 0.55, net_profit -> -1103.4, ext_sales_price -> 33.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 1136.4, hdemo_sk -> 2519.0]]                 |
# |[A -> [ext_list_price -> 3738.0, net_paid_inc_tax -> 1453.24, net_paid -> 1345.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 79.88, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 40.0, item_sk -> 28729, ext_tax -> 107.64, list_price -> 93.45, ticket_number -> 173554050, promo_sk -> 1129.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 33.64, net_profit -> -1849.6, ext_sales_price -> 1345.6, customer_sk -> 1673235.0, ext_wholesale_cost -> 3195.2, hdemo_sk -> 5889.0]]        |
# |[A -> [ext_list_price -> 190.05, net_paid_inc_tax -> 50.29, net_paid -> 48.36, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 23.82, cdemo_sk -> 705962.0, ext_discount_amt -> 23.81, quantity -> 7.0, item_sk -> 84853, ext_tax -> 1.93, list_price -> 27.15, ticket_number -> 173554050, promo_sk -> 110.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 23.81, sales_price -> 10.31, net_profit -> -118.38, ext_sales_price -> 72.17, customer_sk -> 1673235.0, ext_wholesale_cost -> 166.74, hdemo_sk -> 5889.0]]            |
# |[A -> [ext_list_price -> 15011.64, net_paid_inc_tax -> 4170.12, net_paid -> 3971.55, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 83.68, cdemo_sk -> 49553.0, ext_discount_amt -> 81.05, quantity -> 92.0, item_sk -> 53440, ext_tax -> 198.57, list_price -> 163.17, ticket_number -> 220188931, promo_sk -> 485.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 81.05, sales_price -> 44.05, net_profit -> -3727.01, ext_sales_price -> 4052.6, customer_sk -> 1020172.0, ext_wholesale_cost -> 7698.56, hdemo_sk -> 4087.0]]|
# |[A -> [ext_list_price -> 274.0, net_paid_inc_tax -> 274.0, net_paid -> 274.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 2.59, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 100.0, item_sk -> 139063, ext_tax -> 0.0, list_price -> 2.74, ticket_number -> 183648904, promo_sk -> 769.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 2.74, net_profit -> 15.0, ext_sales_price -> 274.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 259.0, hdemo_sk -> 5819.0]]                     |
# |[A -> [ext_list_price -> 2891.61, net_paid_inc_tax -> 661.56, net_paid -> 636.12, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 32.11, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 57.0, item_sk -> 19075, ext_tax -> 25.44, list_price -> 50.73, ticket_number -> 173554050, promo_sk -> 830.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 11.16, net_profit -> -1194.15, ext_sales_price -> 636.12, customer_sk -> 1673235.0, ext_wholesale_cost -> 1830.27, hdemo_sk -> 5889.0]]        |
# |[A -> [ext_list_price -> 5449.6, net_paid_inc_tax -> 2397.6, net_paid -> 2397.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 37.64, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 80.0, item_sk -> 67807, ext_tax -> 0.0, list_price -> 68.12, ticket_number -> 183648904, promo_sk -> 1014.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 29.97, net_profit -> -613.6, ext_sales_price -> 2397.6, customer_sk -> 3422434.0, ext_wholesale_cost -> 3011.2, hdemo_sk -> 5819.0]]            |
# |[A -> [ext_list_price -> 533.8, net_paid_inc_tax -> 48.96, net_paid -> 48.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 45.24, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 10.0, item_sk -> 187726, ext_tax -> 0.96, list_price -> 53.38, ticket_number -> 220188931, promo_sk -> 790.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 4.8, net_profit -> -404.4, ext_sales_price -> 48.0, customer_sk -> 1020172.0, ext_wholesale_cost -> 452.4, hdemo_sk -> 4087.0]]                      |
# |[A -> [ext_list_price -> 1049.28, net_paid_inc_tax -> 320.19, net_paid -> 293.76, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 69.4, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 12.0, item_sk -> 200822, ext_tax -> 26.43, list_price -> 87.44, ticket_number -> 220188931, promo_sk -> 288.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 24.48, net_profit -> -539.04, ext_sales_price -> 293.76, customer_sk -> 1020172.0, ext_wholesale_cost -> 832.8, hdemo_sk -> 4087.0]]            |
# |[A -> [ext_list_price -> 3186.4, net_paid_inc_tax -> 1451.47, net_paid -> 1395.65, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 47.82, cdemo_sk -> 49553.0, ext_discount_amt -> 516.19, quantity -> 56.0, item_sk -> 278278, ext_tax -> 55.82, list_price -> 56.9, ticket_number -> 220188931, promo_sk -> 138.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 516.19, sales_price -> 34.14, net_profit -> -1282.27, ext_sales_price -> 1911.84, customer_sk -> 1020172.0, ext_wholesale_cost -> 2677.92, hdemo_sk -> 4087.0]] |
# |[A -> [ext_list_price -> 4620.33, net_paid_inc_tax -> 699.93, net_paid -> 693.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 81.88, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 33.0, item_sk -> 164011, ext_tax -> 6.93, list_price -> 140.01, ticket_number -> 183648904, promo_sk -> 730.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 21.0, net_profit -> -2009.04, ext_sales_price -> 693.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 2702.04, hdemo_sk -> 5819.0]]         |
# |[A -> [ext_list_price -> 9495.9, net_paid_inc_tax -> 7658.66, net_paid -> 7026.3, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 78.74, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 90.0, item_sk -> 297448, ext_tax -> 632.36, list_price -> 105.51, ticket_number -> 28702045, promo_sk -> 1236.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.07, net_profit -> -60.3, ext_sales_price -> 7026.3, customer_sk -> 8820136.0, ext_wholesale_cost -> 7086.6, hdemo_sk -> 2519.0]]        |
# |[A -> [ext_list_price -> 1882.44, net_paid_inc_tax -> 1097.58, net_paid -> 1016.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.89, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 27.0, item_sk -> 208819, ext_tax -> 81.3, list_price -> 69.72, ticket_number -> 220188931, promo_sk -> 315.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 37.64, net_profit -> 20.25, ext_sales_price -> 1016.28, customer_sk -> 1020172.0, ext_wholesale_cost -> 996.03, hdemo_sk -> 4087.0]]          |
# |[A -> [ext_list_price -> 7129.56, net_paid_inc_tax -> 7160.65, net_paid -> 6630.24, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 48.11, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 76.0, item_sk -> 169159, ext_tax -> 530.41, list_price -> 93.81, ticket_number -> 183648904, promo_sk -> 1128.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 87.24, net_profit -> 2973.88, ext_sales_price -> 6630.24, customer_sk -> 3422434.0, ext_wholesale_cost -> 3656.36, hdemo_sk -> 5819.0]]  |
# |[A -> [ext_list_price -> 10972.5, net_paid_inc_tax -> 5517.88, net_paid -> 5156.9, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 99.21, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 70.0, item_sk -> 195668, ext_tax -> 360.98, list_price -> 156.75, ticket_number -> 183648904, promo_sk -> 1344.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 73.67, net_profit -> -1787.8, ext_sales_price -> 5156.9, customer_sk -> 3422434.0, ext_wholesale_cost -> 6944.7, hdemo_sk -> 5819.0]]    |
# |[A -> [ext_list_price -> 6557.58, net_paid_inc_tax -> 68.54, net_paid -> 65.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 69.13, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 51.0, item_sk -> 237896, ext_tax -> 3.26, list_price -> 128.58, ticket_number -> 28702045, promo_sk -> 37.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 1.28, net_profit -> -3460.35, ext_sales_price -> 65.28, customer_sk -> 8820136.0, ext_wholesale_cost -> 3525.63, hdemo_sk -> 2519.0]]            |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
df3 = df2.select(df2.data.getItem(0).alias('part0'), df2.data.getItem(1).alias('part1'), df2.data.getItem(2).alias('part2'))
df3.show(truncate=False)
# Out:
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |part0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |part1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |part2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[A -> [ext_list_price -> 1556.94, net_paid_inc_tax -> 737.58, net_paid -> 716.1, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.67, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 22.0, item_sk -> 41408, ext_tax -> 21.48, list_price -> 70.77, ticket_number -> 220188931, promo_sk -> 852.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 32.55, net_profit -> -90.64, ext_sales_price -> 716.1, customer_sk -> 1020172.0, ext_wholesale_cost -> 806.74, hdemo_sk -> 4087.0]]              |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> smoke, class_id -> 4.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 12.0, formulation -> 71metallic0275295382, class -> school-uniforms, brand -> edu packexporti #1, wholesale_cost_b -> 0.95, manufact_id -> 489.0, item_desc -> Members shall withstand short, mad procedures. Good, regional films used to contend too., item_id -> AAAAAAAAAMBKAAAA, product_name -> eingbareseoughtese, brand_id -> 3004001.0, size -> extra large, manufact -> n steingese, current_price -> 1.29, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]]                                                                                                 |
# |[A -> [ext_list_price -> 1296.0, net_paid_inc_tax -> 864.96, net_paid -> 816.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 10.87, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 75.0, item_sk -> 12724, ext_tax -> 48.96, list_price -> 17.28, ticket_number -> 28702045, promo_sk -> 145.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 10.88, net_profit -> 0.75, ext_sales_price -> 816.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 815.25, hdemo_sk -> 2519.0]]                |[B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]]|[C -> [container -> Unknown, country -> United States, color -> steel, class_id -> 12.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 7.0, manager_id -> 64.0, formulation -> 91452chartreuse69324, class -> paint, brand -> importonameless #5, wholesale_cost_b -> 3.65, manufact_id -> 488.0, item_desc -> Together young farmers need of course following officers. Early beans gain there continental animals. Local, his, item_id -> AAAAAAAAELBDAAAA, product_name -> eseableationableought, brand_id -> 7012005.0, size -> nan, manufact -> eingeingese, current_price -> 4.94, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Home]]                                                                                              |
# |[A -> [ext_list_price -> 7357.88, net_paid_inc_tax -> 4698.55, net_paid -> 4561.7, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 91.93, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 58.0, item_sk -> 62191, ext_tax -> 136.85, list_price -> 126.86, ticket_number -> 173554050, promo_sk -> 345.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.65, net_profit -> -770.24, ext_sales_price -> 4561.7, customer_sk -> 1673235.0, ext_wholesale_cost -> 5331.94, hdemo_sk -> 5889.0]]      |[B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]]                                                       |[C -> [container -> Unknown, country -> United States, color -> sandy, class_id -> 3.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 1.0, formulation -> 9613lemon44338051332, class -> pants, brand -> exportiimporto #2, wholesale_cost_b -> 2.12, manufact_id -> 370.0, item_desc -> Public provisions would not bring thus well unable women. Gay, opening records increase almost local, capital organisers. White, concerned , item_id -> AAAAAAAAPOCPAAAA, product_name -> oughtn stoughtablecally, brand_id -> 2003002.0, size -> extra large, manufact -> barationpri, current_price -> 6.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]                                                                |
# |[A -> [ext_list_price -> 1463.52, net_paid_inc_tax -> 270.93, net_paid -> 263.04, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 16.94, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 48.0, item_sk -> 52790, ext_tax -> 7.89, list_price -> 30.49, ticket_number -> 220188931, promo_sk -> 44.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 5.48, net_profit -> -550.08, ext_sales_price -> 263.04, customer_sk -> 1020172.0, ext_wholesale_cost -> 813.12, hdemo_sk -> 4087.0]]              |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> floral, class_id -> 5.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 6.0, manager_id -> 2.0, formulation -> seashell957944023811, class -> earings, brand -> scholarcorp #7, wholesale_cost_b -> 1.39, manufact_id -> 355.0, item_desc -> Waste purpose, item_id -> AAAAAAAAGDOMAAAA, product_name -> barn stationableanti, brand_id -> 6005007.0, size -> nan, manufact -> antiantipri, current_price -> 3.77, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Jewelry]]                                                                                                                                                                                               |
# |[A -> [ext_list_price -> 1659.0, net_paid_inc_tax -> 34.32, net_paid -> 33.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 18.94, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 60.0, item_sk -> 102334, ext_tax -> 1.32, list_price -> 27.65, ticket_number -> 28702045, promo_sk -> 888.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 0.55, net_profit -> -1103.4, ext_sales_price -> 33.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 1136.4, hdemo_sk -> 2519.0]]                 |[B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]]|[C -> [container -> Unknown, country -> United States, color -> chocolate, class_id -> 14.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 498138510204rosy8801, class -> tennis, brand -> edu packmaxi #5, wholesale_cost_b -> 2.75, manufact_id -> 218.0, item_desc -> Hands , item_id -> AAAAAAAAOLPIBAAA, product_name -> esepripriablebarought, brand_id -> 8014005.0, size -> nan, manufact -> eingoughtable, current_price -> 4.17, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Sports]]                                                                                                                                                                                                  |
# |[A -> [ext_list_price -> 3738.0, net_paid_inc_tax -> 1453.24, net_paid -> 1345.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 79.88, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 40.0, item_sk -> 28729, ext_tax -> 107.64, list_price -> 93.45, ticket_number -> 173554050, promo_sk -> 1129.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 33.64, net_profit -> -1849.6, ext_sales_price -> 1345.6, customer_sk -> 1673235.0, ext_wholesale_cost -> 3195.2, hdemo_sk -> 5889.0]]        |[B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]]                                                       |[C -> [container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 8.0, formulation -> 7653metallic23918651, class -> school-uniforms, brand -> edu packexporti #2, wholesale_cost_b -> 1.93, manufact_id -> 627.0, item_desc -> Days can include then political periods. Now great players will not know. Cheap, domestic tiles say finally eastern tests. Environmental, good communities can claim in a ministers. Extr, item_id -> AAAAAAAAJDAHAAAA, product_name -> n stableationeingable, brand_id -> 3004002.0, size -> medium, manufact -> ationablecally, current_price -> 3.07, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Children]]       |
# |[A -> [ext_list_price -> 190.05, net_paid_inc_tax -> 50.29, net_paid -> 48.36, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 23.82, cdemo_sk -> 705962.0, ext_discount_amt -> 23.81, quantity -> 7.0, item_sk -> 84853, ext_tax -> 1.93, list_price -> 27.15, ticket_number -> 173554050, promo_sk -> 110.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 23.81, sales_price -> 10.31, net_profit -> -118.38, ext_sales_price -> 72.17, customer_sk -> 1673235.0, ext_wholesale_cost -> 166.74, hdemo_sk -> 5889.0]]            |[B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]]                                                       |[C -> [container -> Unknown, country -> United States, color -> cyan, class_id -> 1.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 4.0, manager_id -> 7.0, formulation -> 449maroon14401579075, class -> womens, brand -> amalgedu pack #2, wholesale_cost_b -> 0.05, manufact_id -> 137.0, item_desc -> International, stro, item_id -> AAAAAAAAFHLEBAAA, product_name -> priantieingeseeing, brand_id -> 4001002.0, size -> medium, manufact -> ationpriought, current_price -> 0.18, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Shoes]]                                                                                                                                                                                               |
# |[A -> [ext_list_price -> 15011.64, net_paid_inc_tax -> 4170.12, net_paid -> 3971.55, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 83.68, cdemo_sk -> 49553.0, ext_discount_amt -> 81.05, quantity -> 92.0, item_sk -> 53440, ext_tax -> 198.57, list_price -> 163.17, ticket_number -> 220188931, promo_sk -> 485.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 81.05, sales_price -> 44.05, net_profit -> -3727.01, ext_sales_price -> 4052.6, customer_sk -> 1020172.0, ext_wholesale_cost -> 7698.56, hdemo_sk -> 4087.0]]|[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> dodger, class_id -> 12.0, tax_precentage -> 0.09, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 10.0, manager_id -> 53.0, formulation -> purple93389253847893, class -> monitors, brand -> importoamalgamalg #10, wholesale_cost_b -> 6.65, manufact_id -> 309.0, item_desc -> Always free loans stay officially at the things. Simple agents develop states. Sudden, royal feet miss results. Spirits may not get thus; public, labour men lay therefore. Popular opponents should, item_id -> AAAAAAAAAMANAAAA, product_name -> bareseeseprianti, brand_id -> 1.001201E7, size -> nan, manufact -> n stbarpri, current_price -> 9.51, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Electronics]]|
# |[A -> [ext_list_price -> 274.0, net_paid_inc_tax -> 274.0, net_paid -> 274.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 2.59, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 100.0, item_sk -> 139063, ext_tax -> 0.0, list_price -> 2.74, ticket_number -> 183648904, promo_sk -> 769.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 2.74, net_profit -> 15.0, ext_sales_price -> 274.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 259.0, hdemo_sk -> 5819.0]]                     |[B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]]                                                  |[C -> [container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.06, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 6.0, formulation -> 07468221505white7068, class -> sports-apparel, brand -> edu packimporto #2, wholesale_cost_b -> 1.0, manufact_id -> 98.0, item_desc -> Late, private hands like never; underlying, ordinary remains could try less, item_id -> AAAAAAAAHDPBCAAA, product_name -> pricallybarn stpriought, brand_id -> 2004002.0, size -> large, manufact -> eingn st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]                                                                                                                                |
# |[A -> [ext_list_price -> 2891.61, net_paid_inc_tax -> 661.56, net_paid -> 636.12, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 32.11, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 57.0, item_sk -> 19075, ext_tax -> 25.44, list_price -> 50.73, ticket_number -> 173554050, promo_sk -> 830.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 11.16, net_profit -> -1194.15, ext_sales_price -> 636.12, customer_sk -> 1673235.0, ext_wholesale_cost -> 1830.27, hdemo_sk -> 5889.0]]        |[B -> [city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]]                                                       |[C -> [container -> Unknown, country -> United States, color -> sandy, class_id -> 2.0, tax_precentage -> 0.09, units -> nan, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 16.0, formulation -> 9149881metallic66497, class -> fragrances, brand -> importoamalg #2, wholesale_cost_b -> 0.58, manufact_id -> 936.0, item_desc -> Big, different principles test in particular. Qualifications could not turn above high types. Errors help here red enquiries; particl, item_id -> AAAAAAAADIKEAAAA, product_name -> antiationbarn stought, brand_id -> 1002002.0, size -> large, manufact -> callyprin st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]]                                                                          |
# |[A -> [ext_list_price -> 5449.6, net_paid_inc_tax -> 2397.6, net_paid -> 2397.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 37.64, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 80.0, item_sk -> 67807, ext_tax -> 0.0, list_price -> 68.12, ticket_number -> 183648904, promo_sk -> 1014.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 29.97, net_profit -> -613.6, ext_sales_price -> 2397.6, customer_sk -> 3422434.0, ext_wholesale_cost -> 3011.2, hdemo_sk -> 5819.0]]            |[B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]]                                                  |[C -> [container -> Unknown, country -> United States, color -> puff, class_id -> 1.0, tax_precentage -> 0.06, units -> Pallet, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 63.0, formulation -> 061995154308tomato83, class -> accessories, brand -> amalgimporto #2, wholesale_cost_b -> 0.52, manufact_id -> 295.0, item_desc -> Prior official years must not waive frequent, silly differences. Specific, colourful interests may not find. Years increase golden disciplines. Still current failures take now th, item_id -> AAAAAAAAPNIABAAA, product_name -> ationbareingationcally, brand_id -> 2001002.0, size -> small, manufact -> antin stable, current_price -> 0.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]]                           |
# |[A -> [ext_list_price -> 533.8, net_paid_inc_tax -> 48.96, net_paid -> 48.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 45.24, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 10.0, item_sk -> 187726, ext_tax -> 0.96, list_price -> 53.38, ticket_number -> 220188931, promo_sk -> 790.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 4.8, net_profit -> -404.4, ext_sales_price -> 48.0, customer_sk -> 1020172.0, ext_wholesale_cost -> 452.4, hdemo_sk -> 4087.0]]                      |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> tan, class_id -> 2.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 61.0, formulation -> 9176519302red4209322, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 0.45, manufact_id -> 316.0, item_desc -> Metres could not create more important, recent eyebrows. Individual elements must like. Working, nuclear reactions get better perhaps other fruits. Options used to want dark, educatio, item_id -> AAAAAAAAOENNCAAA, product_name -> callyableationationeingought, brand_id -> 2002001.0, size -> medium, manufact -> callyoughtpri, current_price -> 1.41, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]]            |
# |[A -> [ext_list_price -> 1049.28, net_paid_inc_tax -> 320.19, net_paid -> 293.76, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 69.4, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 12.0, item_sk -> 200822, ext_tax -> 26.43, list_price -> 87.44, ticket_number -> 220188931, promo_sk -> 288.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 24.48, net_profit -> -539.04, ext_sales_price -> 293.76, customer_sk -> 1020172.0, ext_wholesale_cost -> 832.8, hdemo_sk -> 4087.0]]            |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> peach, class_id -> 2.0, tax_precentage -> 0.09, units -> Ton, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 2.0, formulation -> 425433slate288781353, class -> infants, brand -> importoexporti #1, wholesale_cost_b -> 1.07, manufact_id -> 388.0, item_desc -> Usually english services cannot say more little states. Domi"nan"t, free managers will see home long-term, middle applications; dreadful, general branch, item_id -> AAAAAAAAGHABDAAA, product_name -> ableableeingbarbarable, brand_id -> 3002001.0, size -> economy, manufact -> eingeingpri, current_price -> 3.26, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]]                                             |
# |[A -> [ext_list_price -> 3186.4, net_paid_inc_tax -> 1451.47, net_paid -> 1395.65, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 47.82, cdemo_sk -> 49553.0, ext_discount_amt -> 516.19, quantity -> 56.0, item_sk -> 278278, ext_tax -> 55.82, list_price -> 56.9, ticket_number -> 220188931, promo_sk -> 138.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 516.19, sales_price -> 34.14, net_profit -> -1282.27, ext_sales_price -> 1911.84, customer_sk -> 1020172.0, ext_wholesale_cost -> 2677.92, hdemo_sk -> 4087.0]] |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> white, class_id -> 2.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 15.0, formulation -> magenta5144903790234, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 2.46, manufact_id -> 653.0, item_desc -> Previous, public patterns could not ove, item_id -> AAAAAAAAGAPDEAAA, product_name -> eingationableeingationable, brand_id -> 2002001.0, size -> medium, manufact -> priantically, current_price -> 4.48, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]]                                                                                                                                                            |
# |[A -> [ext_list_price -> 4620.33, net_paid_inc_tax -> 699.93, net_paid -> 693.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 81.88, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 33.0, item_sk -> 164011, ext_tax -> 6.93, list_price -> 140.01, ticket_number -> 183648904, promo_sk -> 730.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 21.0, net_profit -> -2009.04, ext_sales_price -> 693.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 2702.04, hdemo_sk -> 5819.0]]         |[B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]]                                                  |[C -> [container -> Unknown, country -> United States, color -> peru, class_id -> 3.0, tax_precentage -> 0.06, units -> Each, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 98.0, formulation -> 73645025cyan74975996, class -> maternity, brand -> exportiamalg #2, wholesale_cost_b -> 6.73, manufact_id -> 339.0, item_desc -> Appropriate, central plans can obtain soon as dramatic par, item_id -> AAAAAAAALKAICAAA, product_name -> oughtoughtbaresecallyought, brand_id -> 1003002.0, size -> extra large, manufact -> n stpripri, current_price -> 8.31, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]]                                                                                                                                             |
# |[A -> [ext_list_price -> 9495.9, net_paid_inc_tax -> 7658.66, net_paid -> 7026.3, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 78.74, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 90.0, item_sk -> 297448, ext_tax -> 632.36, list_price -> 105.51, ticket_number -> 28702045, promo_sk -> 1236.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.07, net_profit -> -60.3, ext_sales_price -> 7026.3, customer_sk -> 8820136.0, ext_wholesale_cost -> 7086.6, hdemo_sk -> 2519.0]]        |[B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]]|[C -> [container -> Unknown, country -> United States, color -> steel, class_id -> 3.0, tax_precentage -> 0.11, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 49.0, formulation -> 81398slate0530344627, class -> maternity, brand -> exportiamalg #1, wholesale_cost_b -> 3.15, manufact_id -> 505.0, item_desc -> Reasonable police go often important, popular parents. Years live perhaps internal children. Ye, item_id -> AAAAAAAAIOJIEAAA, product_name -> eingeseeseationn stable, brand_id -> 1003001.0, size -> extra large, manufact -> antibaranti, current_price -> 3.75, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Women]]                                                                                                |
# |[A -> [ext_list_price -> 1882.44, net_paid_inc_tax -> 1097.58, net_paid -> 1016.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.89, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 27.0, item_sk -> 208819, ext_tax -> 81.3, list_price -> 69.72, ticket_number -> 220188931, promo_sk -> 315.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 37.64, net_profit -> 20.25, ext_sales_price -> 1016.28, customer_sk -> 1020172.0, ext_wholesale_cost -> 996.03, hdemo_sk -> 4087.0]]          |[B -> [city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]]        |[C -> [container -> Unknown, country -> United States, color -> rosy, class_id -> 2.0, tax_precentage -> 0.09, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 5.0, manager_id -> 39.0, formulation -> 8321770medium0611592, class -> country, brand -> importoscholar #2, wholesale_cost_b -> 0.6, manufact_id -> 238.0, item_desc -> Both national visitors could develop please in a drawings. Free recommendations, item_id -> AAAAAAAADLPCDAAA, product_name -> n stoughteingeingbarable, brand_id -> 5002002.0, size -> nan, manufact -> eingpriable, current_price -> 1.32, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Music]]                                                                                                                               |
# |[A -> [ext_list_price -> 7129.56, net_paid_inc_tax -> 7160.65, net_paid -> 6630.24, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 48.11, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 76.0, item_sk -> 169159, ext_tax -> 530.41, list_price -> 93.81, ticket_number -> 183648904, promo_sk -> 1128.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 87.24, net_profit -> 2973.88, ext_sales_price -> 6630.24, customer_sk -> 3422434.0, ext_wholesale_cost -> 3656.36, hdemo_sk -> 5819.0]]  |[B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]]                                                  |[C -> [container -> Unknown, country -> United States, color -> sienna, class_id -> 11.0, tax_precentage -> 0.06, units -> Box, rec_start_date_b -> 1997-10-27, category_id -> 9.0, manager_id -> 33.0, formulation -> 421salmon06995416651, class -> cooking, brand -> amalgunivamalg #8, wholesale_cost_b -> 1.49, manufact_id -> 541.0, item_desc -> Hands cannot turn annual, economic topics. Enormous, local women praise to a fears. British problems must not increase suddenly complicated years. Her, item_id -> AAAAAAAAHMEJCAAA, product_name -> n stantioughtn stcallyought, brand_id -> 9011008.0, size -> nan, manufact -> oughteseanti, current_price -> 4.28, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Books]]                                                    |
# |[A -> [ext_list_price -> 10972.5, net_paid_inc_tax -> 5517.88, net_paid -> 5156.9, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 99.21, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 70.0, item_sk -> 195668, ext_tax -> 360.98, list_price -> 156.75, ticket_number -> 183648904, promo_sk -> 1344.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 73.67, net_profit -> -1787.8, ext_sales_price -> 5156.9, customer_sk -> 3422434.0, ext_wholesale_cost -> 6944.7, hdemo_sk -> 5819.0]]    |[B -> [city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]]                                                  |[C -> [container -> Unknown, country -> United States, color -> rosy, class_id -> 8.0, tax_precentage -> 0.06, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 9391plum055252741816, class -> outdoor, brand -> namelessnameless #9, wholesale_cost_b -> 3.53, manufact_id -> 531.0, item_desc -> Black, steep figures should show., item_id -> AAAAAAAAEFMPCAAA, product_name -> eingcallycallyantin stought, brand_id -> 8008009.0, size -> nan, manufact -> oughtprianti, current_price -> 4.98, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Sports]]                                                                                                                                                                   |
# |[A -> [ext_list_price -> 6557.58, net_paid_inc_tax -> 68.54, net_paid -> 65.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 69.13, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 51.0, item_sk -> 237896, ext_tax -> 3.26, list_price -> 128.58, ticket_number -> 28702045, promo_sk -> 37.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 1.28, net_profit -> -3460.35, ext_sales_price -> 65.28, customer_sk -> 8820136.0, ext_wholesale_cost -> 3525.63, hdemo_sk -> 2519.0]]            |[B -> [city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]]|[C -> [container -> Unknown, country -> United States, color -> smoke, class_id -> 3.0, tax_precentage -> 0.11, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 69.0, formulation -> 3168761438497slate28, class -> pants, brand -> exportiimporto #1, wholesale_cost_b -> 2.24, manufact_id -> 131.0, item_desc -> Flowers should try from a rooms. Primari, item_id -> AAAAAAAAIEBKDAAA, product_name -> callyn steingationpriable, brand_id -> 2003001.0, size -> extra large, manufact -> oughtpriought, current_price -> 4.08, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Men]]                                                                                                                                                        |
# +----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
df4 = df3.select(df3.part0.getItem('A').alias('part00'), df3.part1.getItem('B').alias('part01'), df3.part2.getItem('C').alias('part02'))
df4.show(truncate=False)
# Out:
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |part00                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |part01                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |part02                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[ext_list_price -> 1556.94, net_paid_inc_tax -> 737.58, net_paid -> 716.1, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.67, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 22.0, item_sk -> 41408, ext_tax -> 21.48, list_price -> 70.77, ticket_number -> 220188931, promo_sk -> 852.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 32.55, net_profit -> -90.64, ext_sales_price -> 716.1, customer_sk -> 1020172.0, ext_wholesale_cost -> 806.74, hdemo_sk -> 4087.0]              |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> smoke, class_id -> 4.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 12.0, formulation -> 71metallic0275295382, class -> school-uniforms, brand -> edu packexporti #1, wholesale_cost_b -> 0.95, manufact_id -> 489.0, item_desc -> Members shall withstand short, mad procedures. Good, regional films used to contend too., item_id -> AAAAAAAAAMBKAAAA, product_name -> eingbareseoughtese, brand_id -> 3004001.0, size -> extra large, manufact -> n steingese, current_price -> 1.29, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]                                                                                                 |
# |[ext_list_price -> 1296.0, net_paid_inc_tax -> 864.96, net_paid -> 816.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 10.87, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 75.0, item_sk -> 12724, ext_tax -> 48.96, list_price -> 17.28, ticket_number -> 28702045, promo_sk -> 145.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 10.88, net_profit -> 0.75, ext_sales_price -> 816.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 815.25, hdemo_sk -> 2519.0]                |[city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]|[container -> Unknown, country -> United States, color -> steel, class_id -> 12.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 7.0, manager_id -> 64.0, formulation -> 91452chartreuse69324, class -> paint, brand -> importonameless #5, wholesale_cost_b -> 3.65, manufact_id -> 488.0, item_desc -> Together young farmers need of course following officers. Early beans gain there continental animals. Local, his, item_id -> AAAAAAAAELBDAAAA, product_name -> eseableationableought, brand_id -> 7012005.0, size -> nan, manufact -> eingeingese, current_price -> 4.94, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Home]                                                                                              |
# |[ext_list_price -> 7357.88, net_paid_inc_tax -> 4698.55, net_paid -> 4561.7, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 91.93, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 58.0, item_sk -> 62191, ext_tax -> 136.85, list_price -> 126.86, ticket_number -> 173554050, promo_sk -> 345.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.65, net_profit -> -770.24, ext_sales_price -> 4561.7, customer_sk -> 1673235.0, ext_wholesale_cost -> 5331.94, hdemo_sk -> 5889.0]      |[city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]                                                       |[container -> Unknown, country -> United States, color -> sandy, class_id -> 3.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 1.0, formulation -> 9613lemon44338051332, class -> pants, brand -> exportiimporto #2, wholesale_cost_b -> 2.12, manufact_id -> 370.0, item_desc -> Public provisions would not bring thus well unable women. Gay, opening records increase almost local, capital organisers. White, concerned , item_id -> AAAAAAAAPOCPAAAA, product_name -> oughtn stoughtablecally, brand_id -> 2003002.0, size -> extra large, manufact -> barationpri, current_price -> 6.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]                                                                |
# |[ext_list_price -> 1463.52, net_paid_inc_tax -> 270.93, net_paid -> 263.04, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 16.94, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 48.0, item_sk -> 52790, ext_tax -> 7.89, list_price -> 30.49, ticket_number -> 220188931, promo_sk -> 44.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 5.48, net_profit -> -550.08, ext_sales_price -> 263.04, customer_sk -> 1020172.0, ext_wholesale_cost -> 813.12, hdemo_sk -> 4087.0]              |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> floral, class_id -> 5.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 6.0, manager_id -> 2.0, formulation -> seashell957944023811, class -> earings, brand -> scholarcorp #7, wholesale_cost_b -> 1.39, manufact_id -> 355.0, item_desc -> Waste purpose, item_id -> AAAAAAAAGDOMAAAA, product_name -> barn stationableanti, brand_id -> 6005007.0, size -> nan, manufact -> antiantipri, current_price -> 3.77, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Jewelry]                                                                                                                                                                                               |
# |[ext_list_price -> 1659.0, net_paid_inc_tax -> 34.32, net_paid -> 33.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 18.94, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 60.0, item_sk -> 102334, ext_tax -> 1.32, list_price -> 27.65, ticket_number -> 28702045, promo_sk -> 888.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 0.55, net_profit -> -1103.4, ext_sales_price -> 33.0, customer_sk -> 8820136.0, ext_wholesale_cost -> 1136.4, hdemo_sk -> 2519.0]                 |[city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]|[container -> Unknown, country -> United States, color -> chocolate, class_id -> 14.0, tax_precentage -> 0.11, units -> Lb, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 498138510204rosy8801, class -> tennis, brand -> edu packmaxi #5, wholesale_cost_b -> 2.75, manufact_id -> 218.0, item_desc -> Hands , item_id -> AAAAAAAAOLPIBAAA, product_name -> esepripriablebarought, brand_id -> 8014005.0, size -> nan, manufact -> eingoughtable, current_price -> 4.17, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Sports]                                                                                                                                                                                                  |
# |[ext_list_price -> 3738.0, net_paid_inc_tax -> 1453.24, net_paid -> 1345.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 79.88, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 40.0, item_sk -> 28729, ext_tax -> 107.64, list_price -> 93.45, ticket_number -> 173554050, promo_sk -> 1129.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 33.64, net_profit -> -1849.6, ext_sales_price -> 1345.6, customer_sk -> 1673235.0, ext_wholesale_cost -> 3195.2, hdemo_sk -> 5889.0]        |[city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]                                                       |[container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.09, units -> Dozen, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 8.0, formulation -> 7653metallic23918651, class -> school-uniforms, brand -> edu packexporti #2, wholesale_cost_b -> 1.93, manufact_id -> 627.0, item_desc -> Days can include then political periods. Now great players will not know. Cheap, domestic tiles say finally eastern tests. Environmental, good communities can claim in a ministers. Extr, item_id -> AAAAAAAAJDAHAAAA, product_name -> n stableationeingable, brand_id -> 3004002.0, size -> medium, manufact -> ationablecally, current_price -> 3.07, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Children]       |
# |[ext_list_price -> 190.05, net_paid_inc_tax -> 50.29, net_paid -> 48.36, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 23.82, cdemo_sk -> 705962.0, ext_discount_amt -> 23.81, quantity -> 7.0, item_sk -> 84853, ext_tax -> 1.93, list_price -> 27.15, ticket_number -> 173554050, promo_sk -> 110.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 23.81, sales_price -> 10.31, net_profit -> -118.38, ext_sales_price -> 72.17, customer_sk -> 1673235.0, ext_wholesale_cost -> 166.74, hdemo_sk -> 5889.0]            |[city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]                                                       |[container -> Unknown, country -> United States, color -> cyan, class_id -> 1.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 4.0, manager_id -> 7.0, formulation -> 449maroon14401579075, class -> womens, brand -> amalgedu pack #2, wholesale_cost_b -> 0.05, manufact_id -> 137.0, item_desc -> International, stro, item_id -> AAAAAAAAFHLEBAAA, product_name -> priantieingeseeing, brand_id -> 4001002.0, size -> medium, manufact -> ationpriought, current_price -> 0.18, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Shoes]                                                                                                                                                                                               |
# |[ext_list_price -> 15011.64, net_paid_inc_tax -> 4170.12, net_paid -> 3971.55, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 83.68, cdemo_sk -> 49553.0, ext_discount_amt -> 81.05, quantity -> 92.0, item_sk -> 53440, ext_tax -> 198.57, list_price -> 163.17, ticket_number -> 220188931, promo_sk -> 485.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 81.05, sales_price -> 44.05, net_profit -> -3727.01, ext_sales_price -> 4052.6, customer_sk -> 1020172.0, ext_wholesale_cost -> 7698.56, hdemo_sk -> 4087.0]|[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> dodger, class_id -> 12.0, tax_precentage -> 0.09, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 10.0, manager_id -> 53.0, formulation -> purple93389253847893, class -> monitors, brand -> importoamalgamalg #10, wholesale_cost_b -> 6.65, manufact_id -> 309.0, item_desc -> Always free loans stay officially at the things. Simple agents develop states. Sudden, royal feet miss results. Spirits may not get thus; public, labour men lay therefore. Popular opponents should, item_id -> AAAAAAAAAMANAAAA, product_name -> bareseeseprianti, brand_id -> 1.001201E7, size -> nan, manufact -> n stbarpri, current_price -> 9.51, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Electronics]|
# |[ext_list_price -> 274.0, net_paid_inc_tax -> 274.0, net_paid -> 274.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 2.59, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 100.0, item_sk -> 139063, ext_tax -> 0.0, list_price -> 2.74, ticket_number -> 183648904, promo_sk -> 769.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 2.74, net_profit -> 15.0, ext_sales_price -> 274.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 259.0, hdemo_sk -> 5819.0]                     |[city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]                                                  |[container -> Unknown, country -> United States, color -> ghost, class_id -> 4.0, tax_precentage -> 0.06, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 6.0, formulation -> 07468221505white7068, class -> sports-apparel, brand -> edu packimporto #2, wholesale_cost_b -> 1.0, manufact_id -> 98.0, item_desc -> Late, private hands like never; underlying, ordinary remains could try less, item_id -> AAAAAAAAHDPBCAAA, product_name -> pricallybarn stpriought, brand_id -> 2004002.0, size -> large, manufact -> eingn st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]                                                                                                                                |
# |[ext_list_price -> 2891.61, net_paid_inc_tax -> 661.56, net_paid -> 636.12, sold_date_sk -> 2450816, store_id -> AAAAAAAAPICAAAAA, wholesale_cost_a -> 32.11, cdemo_sk -> 705962.0, ext_discount_amt -> 0.0, quantity -> 57.0, item_sk -> 19075, ext_tax -> 25.44, list_price -> 50.73, ticket_number -> 173554050, promo_sk -> 830.0, store_sk -> 655.0, addr_sk -> 1099416.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 11.16, net_profit -> -1194.15, ext_sales_price -> 636.12, customer_sk -> 1673235.0, ext_wholesale_cost -> 1830.27, hdemo_sk -> 5889.0]        |[city -> Buena Vista, floor_space -> 9838083.0, county -> Barrow County, market_desc -> Sometimes important pupils find exis, street_name -> 2nd Green, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> anti, state -> GA, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite 360, company_id -> 1.0, manager -> Kimberly Norris, division_id -> 1.0, market_id -> 9.0, closed_date_sk -> nan, market_manager -> Douglas Boettcher, company_name -> Unknown, street_number -> 978.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 254.0, rec_end_date_a -> nan]                                                       |[container -> Unknown, country -> United States, color -> sandy, class_id -> 2.0, tax_precentage -> 0.09, units -> nan, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 16.0, formulation -> 9149881metallic66497, class -> fragrances, brand -> importoamalg #2, wholesale_cost_b -> 0.58, manufact_id -> 936.0, item_desc -> Big, different principles test in particular. Qualifications could not turn above high types. Errors help here red enquiries; particl, item_id -> AAAAAAAADIKEAAAA, product_name -> antiationbarn stought, brand_id -> 1002002.0, size -> large, manufact -> callyprin st, current_price -> 1.55, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]                                                                          |
# |[ext_list_price -> 5449.6, net_paid_inc_tax -> 2397.6, net_paid -> 2397.6, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 37.64, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 80.0, item_sk -> 67807, ext_tax -> 0.0, list_price -> 68.12, ticket_number -> 183648904, promo_sk -> 1014.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 29.97, net_profit -> -613.6, ext_sales_price -> 2397.6, customer_sk -> 3422434.0, ext_wholesale_cost -> 3011.2, hdemo_sk -> 5819.0]            |[city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]                                                  |[container -> Unknown, country -> United States, color -> puff, class_id -> 1.0, tax_precentage -> 0.06, units -> Pallet, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 63.0, formulation -> 061995154308tomato83, class -> accessories, brand -> amalgimporto #2, wholesale_cost_b -> 0.52, manufact_id -> 295.0, item_desc -> Prior official years must not waive frequent, silly differences. Specific, colourful interests may not find. Years increase golden disciplines. Still current failures take now th, item_id -> AAAAAAAAPNIABAAA, product_name -> ationbareingationcally, brand_id -> 2001002.0, size -> small, manufact -> antin stable, current_price -> 0.84, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Men]                           |
# |[ext_list_price -> 533.8, net_paid_inc_tax -> 48.96, net_paid -> 48.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 45.24, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 10.0, item_sk -> 187726, ext_tax -> 0.96, list_price -> 53.38, ticket_number -> 220188931, promo_sk -> 790.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 4.8, net_profit -> -404.4, ext_sales_price -> 48.0, customer_sk -> 1020172.0, ext_wholesale_cost -> 452.4, hdemo_sk -> 4087.0]                      |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> tan, class_id -> 2.0, tax_precentage -> 0.09, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 61.0, formulation -> 9176519302red4209322, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 0.45, manufact_id -> 316.0, item_desc -> Metres could not create more important, recent eyebrows. Individual elements must like. Working, nuclear reactions get better perhaps other fruits. Options used to want dark, educatio, item_id -> AAAAAAAAOENNCAAA, product_name -> callyableationationeingought, brand_id -> 2002001.0, size -> medium, manufact -> callyoughtpri, current_price -> 1.41, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]            |
# |[ext_list_price -> 1049.28, net_paid_inc_tax -> 320.19, net_paid -> 293.76, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 69.4, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 12.0, item_sk -> 200822, ext_tax -> 26.43, list_price -> 87.44, ticket_number -> 220188931, promo_sk -> 288.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 24.48, net_profit -> -539.04, ext_sales_price -> 293.76, customer_sk -> 1020172.0, ext_wholesale_cost -> 832.8, hdemo_sk -> 4087.0]            |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> peach, class_id -> 2.0, tax_precentage -> 0.09, units -> Ton, rec_start_date_b -> 1997-10-27, category_id -> 3.0, manager_id -> 2.0, formulation -> 425433slate288781353, class -> infants, brand -> importoexporti #1, wholesale_cost_b -> 1.07, manufact_id -> 388.0, item_desc -> Usually english services cannot say more little states. Domi"nan"t, free managers will see home long-term, middle applications; dreadful, general branch, item_id -> AAAAAAAAGHABDAAA, product_name -> ableableeingbarbarable, brand_id -> 3002001.0, size -> economy, manufact -> eingeingpri, current_price -> 3.26, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Children]                                             |
# |[ext_list_price -> 3186.4, net_paid_inc_tax -> 1451.47, net_paid -> 1395.65, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 47.82, cdemo_sk -> 49553.0, ext_discount_amt -> 516.19, quantity -> 56.0, item_sk -> 278278, ext_tax -> 55.82, list_price -> 56.9, ticket_number -> 220188931, promo_sk -> 138.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 516.19, sales_price -> 34.14, net_profit -> -1282.27, ext_sales_price -> 1911.84, customer_sk -> 1020172.0, ext_wholesale_cost -> 2677.92, hdemo_sk -> 4087.0] |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> white, class_id -> 2.0, tax_precentage -> 0.09, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 15.0, formulation -> magenta5144903790234, class -> shirts, brand -> importoimporto #1, wholesale_cost_b -> 2.46, manufact_id -> 653.0, item_desc -> Previous, public patterns could not ove, item_id -> AAAAAAAAGAPDEAAA, product_name -> eingationableeingationable, brand_id -> 2002001.0, size -> medium, manufact -> priantically, current_price -> 4.48, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Men]                                                                                                                                                            |
# |[ext_list_price -> 4620.33, net_paid_inc_tax -> 699.93, net_paid -> 693.0, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 81.88, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 33.0, item_sk -> 164011, ext_tax -> 6.93, list_price -> 140.01, ticket_number -> 183648904, promo_sk -> 730.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 21.0, net_profit -> -2009.04, ext_sales_price -> 693.0, customer_sk -> 3422434.0, ext_wholesale_cost -> 2702.04, hdemo_sk -> 5819.0]         |[city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]                                                  |[container -> Unknown, country -> United States, color -> peru, class_id -> 3.0, tax_precentage -> 0.06, units -> Each, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 98.0, formulation -> 73645025cyan74975996, class -> maternity, brand -> exportiamalg #2, wholesale_cost_b -> 6.73, manufact_id -> 339.0, item_desc -> Appropriate, central plans can obtain soon as dramatic par, item_id -> AAAAAAAALKAICAAA, product_name -> oughtoughtbaresecallyought, brand_id -> 1003002.0, size -> extra large, manufact -> n stpripri, current_price -> 8.31, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Women]                                                                                                                                             |
# |[ext_list_price -> 9495.9, net_paid_inc_tax -> 7658.66, net_paid -> 7026.3, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 78.74, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 90.0, item_sk -> 297448, ext_tax -> 632.36, list_price -> 105.51, ticket_number -> 28702045, promo_sk -> 1236.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 78.07, net_profit -> -60.3, ext_sales_price -> 7026.3, customer_sk -> 8820136.0, ext_wholesale_cost -> 7086.6, hdemo_sk -> 2519.0]        |[city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]|[container -> Unknown, country -> United States, color -> steel, class_id -> 3.0, tax_precentage -> 0.11, units -> Carton, rec_start_date_b -> 1997-10-27, category_id -> 1.0, manager_id -> 49.0, formulation -> 81398slate0530344627, class -> maternity, brand -> exportiamalg #1, wholesale_cost_b -> 3.15, manufact_id -> 505.0, item_desc -> Reasonable police go often important, popular parents. Years live perhaps internal children. Ye, item_id -> AAAAAAAAIOJIEAAA, product_name -> eingeseeseationn stable, brand_id -> 1003001.0, size -> extra large, manufact -> antibaranti, current_price -> 3.75, rec_end_date_b -> 1999-10-27, gmt_offset -> -5.0, category -> Women]                                                                                                |
# |[ext_list_price -> 1882.44, net_paid_inc_tax -> 1097.58, net_paid -> 1016.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAGBAAAAA, wholesale_cost_a -> 36.89, cdemo_sk -> 49553.0, ext_discount_amt -> 0.0, quantity -> 27.0, item_sk -> 208819, ext_tax -> 81.3, list_price -> 69.72, ticket_number -> 220188931, promo_sk -> 315.0, store_sk -> 352.0, addr_sk -> 1781021.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 37.64, net_profit -> 20.25, ext_sales_price -> 1016.28, customer_sk -> 1020172.0, ext_wholesale_cost -> 996.03, hdemo_sk -> 4087.0]          |[city -> Oakdale, floor_space -> 6383749.0, county -> Dauphin County, market_desc -> Indeed secret factors might not keep else computers. Deep, physical speakers shou, street_name -> Railroad Maple, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> able, state -> PA, zip -> 19584.0, hours -> 8AM-4PM, suite_number -> Suite 10, company_id -> 1.0, manager -> Marcus Watkins, division_id -> 1.0, market_id -> 7.0, closed_date_sk -> nan, market_manager -> James Kilgore, company_name -> Unknown, street_number -> 749.0, division_name -> Unknown, street_type -> Drive, number_employees -> 257.0, rec_end_date_a -> 1999-03-13]        |[container -> Unknown, country -> United States, color -> rosy, class_id -> 2.0, tax_precentage -> 0.09, units -> Unknown, rec_start_date_b -> 1997-10-27, category_id -> 5.0, manager_id -> 39.0, formulation -> 8321770medium0611592, class -> country, brand -> importoscholar #2, wholesale_cost_b -> 0.6, manufact_id -> 238.0, item_desc -> Both national visitors could develop please in a drawings. Free recommendations, item_id -> AAAAAAAADLPCDAAA, product_name -> n stoughteingeingbarable, brand_id -> 5002002.0, size -> nan, manufact -> eingpriable, current_price -> 1.32, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Music]                                                                                                                               |
# |[ext_list_price -> 7129.56, net_paid_inc_tax -> 7160.65, net_paid -> 6630.24, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 48.11, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 76.0, item_sk -> 169159, ext_tax -> 530.41, list_price -> 93.81, ticket_number -> 183648904, promo_sk -> 1128.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 87.24, net_profit -> 2973.88, ext_sales_price -> 6630.24, customer_sk -> 3422434.0, ext_wholesale_cost -> 3656.36, hdemo_sk -> 5819.0]  |[city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]                                                  |[container -> Unknown, country -> United States, color -> sienna, class_id -> 11.0, tax_precentage -> 0.06, units -> Box, rec_start_date_b -> 1997-10-27, category_id -> 9.0, manager_id -> 33.0, formulation -> 421salmon06995416651, class -> cooking, brand -> amalgunivamalg #8, wholesale_cost_b -> 1.49, manufact_id -> 541.0, item_desc -> Hands cannot turn annual, economic topics. Enormous, local women praise to a fears. British problems must not increase suddenly complicated years. Her, item_id -> AAAAAAAAHMEJCAAA, product_name -> n stantioughtn stcallyought, brand_id -> 9011008.0, size -> nan, manufact -> oughteseanti, current_price -> 4.28, rec_end_date_b -> nan, gmt_offset -> -5.0, category -> Books]                                                    |
# |[ext_list_price -> 10972.5, net_paid_inc_tax -> 5517.88, net_paid -> 5156.9, sold_date_sk -> 2450816, store_id -> AAAAAAAAABDAAAAA, wholesale_cost_a -> 99.21, cdemo_sk -> 1063903.0, ext_discount_amt -> 0.0, quantity -> 70.0, item_sk -> 195668, ext_tax -> 360.98, list_price -> 156.75, ticket_number -> 183648904, promo_sk -> 1344.0, store_sk -> 784.0, addr_sk -> 3145688.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 73.67, net_profit -> -1787.8, ext_sales_price -> 5156.9, customer_sk -> 3422434.0, ext_wholesale_cost -> 6944.7, hdemo_sk -> 5819.0]    |[city -> Buena Vista, floor_space -> 5794892.0, county -> Williamson County, market_desc -> Yesterday big things may make col, street_name -> North Hickory, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> ese, state -> TN, zip -> 35752.0, hours -> 8AM-4PM, suite_number -> Suite H, company_id -> 1.0, manager -> David Crockett, division_id -> 1.0, market_id -> 4.0, closed_date_sk -> nan, market_manager -> Helen Gonzales, company_name -> Unknown, street_number -> 743.0, division_name -> Unknown, street_type -> Street, number_employees -> 258.0, rec_end_date_a -> 1999-03-13]                                                  |[container -> Unknown, country -> United States, color -> rosy, class_id -> 8.0, tax_precentage -> 0.06, units -> Oz, rec_start_date_b -> 1997-10-27, category_id -> 8.0, manager_id -> 24.0, formulation -> 9391plum055252741816, class -> outdoor, brand -> namelessnameless #9, wholesale_cost_b -> 3.53, manufact_id -> 531.0, item_desc -> Black, steep figures should show., item_id -> AAAAAAAAEFMPCAAA, product_name -> eingcallycallyantin stought, brand_id -> 8008009.0, size -> nan, manufact -> oughtprianti, current_price -> 4.98, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Sports]                                                                                                                                                                   |
# |[ext_list_price -> 6557.58, net_paid_inc_tax -> 68.54, net_paid -> 65.28, sold_date_sk -> 2450816, store_id -> AAAAAAAAAPBAAAAA, wholesale_cost_a -> 69.13, cdemo_sk -> 1693904.0, ext_discount_amt -> 0.0, quantity -> 51.0, item_sk -> 237896, ext_tax -> 3.26, list_price -> 128.58, ticket_number -> 28702045, promo_sk -> 37.0, store_sk -> 496.0, addr_sk -> 2438687.0, sold_time_sk -> 51106, coupon_amt -> 0.0, sales_price -> 1.28, net_profit -> -3460.35, ext_sales_price -> 65.28, customer_sk -> 8820136.0, ext_wholesale_cost -> 3525.63, hdemo_sk -> 2519.0]            |[city -> Oak Hill, floor_space -> 9953651.0, county -> Williamson County, market_desc -> There visible waves operate as wrong solutions. Junior factors used to run frequently to, street_name -> 7th Adams, geography_class -> Unknown, rec_start_date_a -> 1997-03-13, store_name -> cally, state -> TN, zip -> 37838.0, hours -> 8AM-4PM, suite_number -> Suite A, company_id -> 1.0, manager -> Sarah Knight, division_id -> 1.0, market_id -> 10.0, closed_date_sk -> 2451273.0, market_manager -> Ira Ortiz, company_name -> Unknown, street_number -> 938.0, division_name -> Unknown, street_type -> Avenue, number_employees -> 252.0, rec_end_date_a -> 1999-03-13]|[container -> Unknown, country -> United States, color -> smoke, class_id -> 3.0, tax_precentage -> 0.11, units -> Ounce, rec_start_date_b -> 1997-10-27, category_id -> 2.0, manager_id -> 69.0, formulation -> 3168761438497slate28, class -> pants, brand -> exportiimporto #1, wholesale_cost_b -> 2.24, manufact_id -> 131.0, item_desc -> Flowers should try from a rooms. Primari, item_id -> AAAAAAAAIEBKDAAA, product_name -> callyn steingationpriable, brand_id -> 2003001.0, size -> extra large, manufact -> oughtpriought, current_price -> 4.08, rec_end_date_b -> 2000-10-26, gmt_offset -> -5.0, category -> Men]                                                                                                                                                        |
# +---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %%
df5 = df4.withColumn('partA', F.map_concat('part00','part01','part02')).select('partA')

# %%
df5.rdd.map(lambda x: x.__getitem__('partA')).toDF().toPandas()
# +--+--+-- => toDF
# DF => print()할때만 toPandas()
# Out:
# NameError: name 'df5' is not defined
